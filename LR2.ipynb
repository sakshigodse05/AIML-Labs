# %%
##Preprocessing done in logistic regression


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix,classification_report
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.preprocessing import LabelEncoder

# %%
traindf=pd.read_csv('/content/train.csv')
testdf=pd.read_csv('/content/test.csv')

# %%
traindf.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
traindf.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
traindf.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
print(traindf.shape)
print(traindf.columns)
# Out:
# (891, 12)
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
traindf.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
traindf['Age']=traindf['Age'].fillna(traindf['Age'].mean())

# %%
traindf.dropna(axis=0,how='any',subset="Embarked",inplace=True)
traindf.drop(axis=1,columns='Cabin',inplace=True)

# %%
traindf.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
traindf.drop("PassengerId",axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-113-c04845e7f36c> in <cell line: 1>()
# ----> 1 traindf.drop("PassengerId",axis=1,inplace=True)
#       2
#       3
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
traindf.head()
# Out:
#    Survived  Pclass  ...     Fare Embarked
# 0         0       3  ...   7.2500        S
# 1         1       1  ...  71.2833        C
# 2         1       3  ...   7.9250        S
# 3         1       1  ...  53.1000        S
# 4         0       3  ...   8.0500        S
#
# [5 rows x 10 columns]

# %%
y_train =traindf['Survived']

# %%
feature=['Pclass','Sex','Age','SibSp','Parch','Ticket','Fare','Cabin']

# %%
testdf['Age']
# Out:
# 0      34.5
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
#        ...
# 413     NaN
# 414    39.0
# 415    38.5
# 416     NaN
# 417     NaN
# Name: Age, Length: 418, dtype: float64

# %%
traindf=pd.get_dummies(traindf,columns=['Sex'])
test=pd.get_dummies(testdf,columns=['Sex'])

# %%
traindf=pd.get_dummies(traindf,columns=['Embarked'])
test=pd.get_dummies(testdf,columns=['Embarked'])

# %%
traindf.head()
# Out:
#    Survived  Pclass  ... Embarked_Q  Embarked_S
# 0         0       3  ...      False        True
# 1         1       1  ...      False       False
# 2         1       3  ...      False        True
# 3         1       1  ...      False        True
# 4         0       3  ...      False        True
#
# [5 rows x 13 columns]

# %%
testdf['Fare']=testdf['Fare'].fillna(testdf['Fare'].mean())

# %%
testdf.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          327
# Embarked         0
# dtype: int64

# %%
testdf.drop(axis=1, columns)

# %%
traindf.drop(axis=1,columns='Ticket',inplace=True)
testdf.drop(axis=1,columns='Ticket',inplace=True)

# %%
traindf
# Out:
#      Survived  Pclass  ... Embarked_Q  Embarked_S
# 0           0       3  ...      False        True
# 1           1       1  ...      False       False
# 2           1       3  ...      False        True
# 3           1       1  ...      False        True
# 4           0       3  ...      False        True
# ..        ...     ...  ...        ...         ...
# 886         0       2  ...      False        True
# 887         1       1  ...      False        True
# 888         0       3  ...      False        True
# 889         1       1  ...      False       False
# 890         0       3  ...       True       False
#
# [889 rows x 12 columns]

# %%
y_train
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 889, dtype: int64

# %%
train_x,val_x,train_y,val_y=train_test_split(traindf,y_train,random_state=52,train_size=0.8)

# %%
train_x
# Out:
#      Survived  Pclass  ... Embarked_Q  Embarked_S
# 739         0       3  ...      False        True
# 120         0       2  ...      False        True
# 641         1       1  ...      False       False
# 160         0       3  ...      False        True
# 56          1       2  ...      False        True
# ..        ...     ...  ...        ...         ...
# 87          0       3  ...      False        True
# 152         0       3  ...      False        True
# 526         1       2  ...      False        True
# 780         1       3  ...      False       False
# 669         1       1  ...      False        True
#
# [711 rows x 12 columns]

# %%
train_y
# Out:
# 739    0
# 120    0
# 641    1
# 160    0
# 56     1
#       ..
# 87     0
# 152    0
# 526    1
# 780    1
# 669    1
# Name: Survived, Length: 711, dtype: int64

# %%
val_x
# Out:
#      Survived  Pclass  ... Embarked_Q  Embarked_S
# 560         0       3  ...       True       False
# 156         1       3  ...       True       False
# 200         0       3  ...      False        True
# 378         0       3  ...      False       False
# 263         0       1  ...      False        True
# ..        ...     ...  ...        ...         ...
# 182         0       3  ...      False        True
# 414         1       3  ...      False        True
# 710         1       1  ...      False       False
# 578         0       3  ...      False       False
# 246         0       3  ...      False        True
#
# [178 rows x 12 columns]

# %%
val_y
# Out:
# 560    0
# 156    1
# 200    0
# 378    0
# 263    0
#       ..
# 182    0
# 414    1
# 710    1
# 578    0
# 246    0
# Name: Survived, Length: 178, dtype: int64

# %%
train_x = pd.get_dummies(train_x, drop_first=True)   ###################

# %% [markdown]
# apply Logistic **regression**

# %%
model=LogisticRegression()

# %%
model.fit(train_x,train_y)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.predict(val_x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-109-261b59ee6f7a> in <cell line: 1>()
# ----> 1 model.predict(val_x)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     380         """
#     381         xp, _ = get_namespace(X)
# --> 382         scores = self.decision_function(X)
#     383         if len(scores.shape) == 1:
#     384             indices = xp.astype(scores > 0, indexing_dtype(xp))
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in decision_function(self, X)
#     361         xp, _ = get_namespace(X)
#     362
# --> 363         X = self._validate_data(X, accept_sparse="csr", reset=False)
#     364         scores = safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     365         return xp.reshape(scores, (-1,)) if scores.shape[1] == 1 else scores
#
# ...

# %%
accuracy_score(val_y,model.predict(val_x))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-107-29201418f10e> in <cell line: 1>()
# ----> 1 accuracy_score(val_y,model.predict(val_x))
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     380         """
#     381         xp, _ = get_namespace(X)
# --> 382         scores = self.decision_function(X)
#     383         if len(scores.shape) == 1:
#     384             indices = xp.astype(scores > 0, indexing_dtype(xp))
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in decision_function(self, X)
#     361         xp, _ = get_namespace(X)
#     362
# --> 363         X = self._validate_data(X, accept_sparse="csr", reset=False)
#     364         scores = safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
# ...

# %%
model.predict_proba(val_x)[:,1]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-98-87e5d348d2ee> in <cell line: 1>()
# ----> 1 model.predict_proba(val_x)[:,1]
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py in predict_proba(self, X)
#    1424             self.multi_class in ["auto", "deprecated"]
#    1425             and (
# -> 1426                 self.classes_.size <= 2
#    1427                 or self.solver in ("liblinear", "newton-cholesky")
#    1428             )
#
# AttributeError: 'LogisticRegression' object has no attribute 'classes_'

# %% [markdown]
# **Logistic regression**
