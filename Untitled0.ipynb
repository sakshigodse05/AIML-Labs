# %%
#_  single variable is hidden variable
#__ double variable is a public variable
#X is when it is a multidimensional
# @ is called decoratar in python which automatically execute
# /first_link => is called zan END point or API End point

# %%
from flask import Flask

# %%
app = Flask(__name__)

# %%
@app.route("/first_link", methods = ['GET'])
def first_flask_function():
   print+("link run successfully")
   return "value returned by the END point"

# %%
#Execute like this: python -m flask --app flask/quickstart.py run
if __name__== "__main__":
    app.run(debug=True)
    print("hello")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug: * Restarting with stat
